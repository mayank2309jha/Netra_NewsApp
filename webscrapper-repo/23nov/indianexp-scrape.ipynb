# %%
CATEGORY_URLS = {
    "india": "https://indianexpress.com/section/india/?ref=l1_section",
    "entertainment": "https://indianexpress.com/section/entertainment/?ref=l1_section",
    "politics": "https://indianexpress.com/politics/?ref=l1_section",
    "sports": "https://indianexpress.com/section/sports/?ref=l1_section",
    "world": "https://indianexpress.com/section/world/?ref=l1_section",
    "business": "https://indianexpress.com/section/business/?ref=l1_section",
    "technology": "https://indianexpress.com/section/technology/?ref=l1_section"
}
JSON_NAMES = {
    "india": "india_news.json",
    "entertainment": "entertainment_news.json",
    "politics": "politics_news.json", 
    "sports": "sports_news.json",
    "world": "world_news.json",
    "business": "business_news.json",
    "technology": "technology_news.json"
}

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup
index = "india"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]

header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)


response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

for art in soup.find_all("div", class_="articles"):
    try:
        img_tag = art.find("div", class_="snaps").find("img") if art.find("div", class_="snaps") else None
        img_url = (img_tag.get("data-src") or img_tag.get("src")) if img_tag else "N/A"

        text = art.find("div", class_="img-context")
        if not text: continue

        a = text.find("h2", class_="title").find("a") if text.find("h2", class_="title") else None
        headline = a.text.strip() if a else "N/A"
        link = a["href"] if a else "N/A"
        date = text.find("div", class_="date").text.strip() if text.find("div", class_="date") else "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": "N/A",
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": "N/A"
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except:
        continue


try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = [] 

updated_data = old_data + final_output

unique = []
links = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in links:
        links.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print("Updated json with", len(final_output), "new articles.")
final_output[0:3]
# Out:
# Updated json with 25 new articles.
# [{'primary_article': {'headline': '5 stories you must read today, November 23: From ‘Interstate’ terror module arrest in J&K to Kolkata hotel murder and more',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/india/express-catch-up-5-stories-you-must-read-today-november-23-10376596-10381866/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/Catch-up.jpg?w=450',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  18:55 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'In first speech after Karur tragedy, Vijay lays out his ideology, equates DMK with ‘syndicate of dacoits’',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/india/karur-tragedy-vijay-dmk-10381948/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/vijay-2.jpg?w=450',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  18:17 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'UNSC reforms no longer an option, but a necessity: PM Modi at IBSA meet',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/india/unsc-reforms-no-longer-an-option-but-a-necessity-pm-modi-at-ibsa-meet-10381764/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/Modi-IBSA.jpg?w=450',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  16:28 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0}]

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup

index = "entertainment"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]
print(url)
print(json_path)

header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)

response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

for art in soup.find_all("article", class_="myie-articles"):
    try:
        img_wrap = art.find("div", class_="myie-snaps")
        img_tag = img_wrap.find("img") if img_wrap else None
        img_url = img_tag.get("data-src") or img_tag.get("src") if img_tag else "N/A"

        title_div = art.find("h2", class_="myie-title")
        a = title_div.find("a") if title_div else None
        headline = a.text.strip() if a else "N/A"
        link = a["href"] if a else "N/A"

        time_div = art.find("div", class_="my-time")
        date = time_div.text.strip() if time_div else "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": "N/A",
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": "N/A"
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except Exception as e:
        print("Error:", e)
        continue

try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []

updated_data = old_data + final_output

unique = []
links = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in links:
        links.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print("Updated json with", len(final_output), "new articles.")
final_output[:3]
# Out:
# https://indianexpress.com/section/entertainment/?ref=l1_section
# entertainment_news.json
# Updated json with 25 new articles.
# [{'primary_article': {'headline': 'Laughter Chefs Season 3 first impression: Vivian Dsena, Tejasswi Prakash, Gurmeet Choudhary join lineup, but chaos overshadows creativity',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/entertainment/television/laughter-chefs-season-3-episode-1-review-rating-cast-where-to-watch-10381700/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/Laughter-Chefs-Season-3-cast.jpg?w=270',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  18:16 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Armaan Jain says Kapoor family came together ‘like an army’ during Sunjay Kapur’s death, Saif Ali Khan’s knife attack: ‘Bouncing back is in our DNA’',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/entertainment/bollywood/armaan-jain-says-kapoor-family-came-together-like-an-army-during-saif-ali-khan-knife-attack-10381469/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/MixCollage-23-Nov-2025-03-09-PM-2189.jpg?w=270',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025 17:26 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Anupam Kher stood on a coffee shop table and shouted to demand fair pay for a film: ‘The producer had just made 100 million’',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/entertainment/bollywood/anupam-kher-stood-on-a-coffee-shop-table-and-shouted-to-demand-fair-pay-for-a-film-10381730/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/anupam-kher.jpg?w=270',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025 17:12 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0}]

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup

index = "politics"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]
print(url)

header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)

response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

wrapper = soup.find("div", class_="opinion-more-wrapper")

if wrapper:
    listing = wrapper.find("div", class_="opinion-more-listing flex")
    
    if listing:
        for art in listing.find_all("div", class_="o-opin-article"):
            try:
                writer = art.find("div", class_="news-writer-name")
                author = "N/A"
                date = "N/A"
                
                if writer:
                    author_link = writer.find("a")
                    if author_link:
                        author = author_link.text.strip()
                    
                    date_span = writer.find("span", class_="opinion-date")
                    if date_span:
                        date = date_span.text.strip()
                
                title = art.find("h4", class_="o-opin-article_title")
                headline = "N/A"
                link = "N/A"
                
                if title:
                    a = title.find("a")
                    if a:
                        headline = a.text.strip()
                        link = a.get("href", "N/A")
                        if link != "N/A" and not link.startswith("http"):
                            link = "https://indianexpress.com" + link
                
                summary_div = art.find("div", class_="opinion-news-para")
                summary = summary_div.text.strip() if summary_div else "N/A"
                
                img_div = art.find("div", class_="opinion-news-figure")
                img_url = "N/A"
                
                if img_div:
                    img_link = img_div.find("a")
                    if img_link:
                        img_tag = img_link.find("img")
                    else:
                        img_tag = img_div.find("img")
                    
                    if img_tag:
                        img_url = img_tag.get("data-src") or img_tag.get("src") or "N/A"
                
                if headline != "N/A":
                    final_output.append({
                        "primary_article": {
                            "headline": headline,
                            "author": author,
                            "article_link": link,
                            "featured_image": img_url,
                            "source_logo": "N/A",
                            "source_name": "IndianExpress",
                            "publish_date": date,
                            "summary": summary
                        },
                        "related_articles": [],
                        "total_related_articles": 0
                    })
                    
            except Exception as e:
                print("Error parsing article:", e)
                continue
    else:
        print("❌ Could not find opinion-more-listing flex")
else:
    print("❌ Could not find opinion-more-wrapper")

print(f"✅ Found {len(final_output)} articles")

try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []

updated_data = old_data + final_output

unique = []
links = set()
for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in links and link != "N/A":
        links.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print(f"✅ Updated json with {len(final_output)} new politics articles.")
print(f"📊 Total unique articles: {len(unique)}")

final_output[:3]
# Out:
# https://indianexpress.com/politics/?ref=l1_section
# ❌ Could not find opinion-more-listing flex
# ✅ Found 0 articles
# ✅ Updated json with 0 new politics articles.
# 📊 Total unique articles: 0
# []

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup
index = "sports"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]
header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)


response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

for art in soup.find_all("div", class_="articles"):
    try:
        img_tag = art.find("div", class_="snaps").find("img") if art.find("div", class_="snaps") else None
        img_url = (img_tag.get("data-src") or img_tag.get("src")) if img_tag else "N/A"

        text = art.find("div", class_="img-context")
        if not text: continue

        a = text.find("h2", class_="title").find("a") if text.find("h2", class_="title") else None
        headline = a.text.strip() if a else "N/A"
        link = a["href"] if a else "N/A"
        date = text.find("div", class_="date").text.strip() if text.find("div", class_="date") else "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": "N/A",
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": "N/A"
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except:
        continue

try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []   # file didn't exist → start fresh

updated_data = old_data + final_output

unique = []
links = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in links:
        links.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print("Updated json with", len(final_output), "new articles.")
final_output[0:3]
# Out:
# Updated json with 25 new articles.
# [{'primary_article': {'headline': 'India vs South Africa 2nd Test | ‘Are they actually bereft of ideas?’: Aakash Chopra wants better planning from bowlers in a pitch like Guwahati',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/sports/cricket/india-vs-south-africa-2nd-test-aakash-chopra-bowlers-bereft-ideas-10381985/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/IND-vs-SA.jpg?resize=450,253',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025 19:04 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'India announce ODI squad for South Africa series: KL Rahul to lead in Shubman Gill’s absence; Rohit Sharma, Virat Kohli feature as Jasprit Bumrah is rested',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/sports/cricket/india-announce-odi-squad-south-africa-kl-rahul-to-lead-kohli-rohit-10381768/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/RAHUL-26.jpg?resize=450,253',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  18:09 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Senuran Muthusamy reacts after scoring century vs India at Guwahati: ‘It was a really special moment in front of this full house’',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/article/sports/cricket/senuran-muthusamy-century-maiden-100-south-africa-india-guwahati-10381852/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/Senuran.jpg?resize=450,253',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'November 23, 2025  17:24 IST',
#    'summary': 'N/A'},
#   'related_articles': [],
#   'total_related_articles': 0}]

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup
index = "world"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]
print(url)
# Load all headers from CSV
header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)


response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

for art in soup.find_all("div", class_="articles"):
    try:
        img_tag = art.find("div", class_="snaps").find("img") if art.find("div", class_="snaps") else None
        img_url = (img_tag.get("data-src") or img_tag.get("src")) if img_tag else "N/A"

        text = art.find("div", class_="img-context")
        if not text: continue

        a = text.find("h2", class_="title").find("a") if text.find("h2", class_="title") else None
        headline = a.text.strip() if a else "N/A"
        link = a["href"] if a else "N/A"
        date = text.find("div", class_="date").text.strip() if text.find("div", class_="date") else "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": "N/A",
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": "N/A"
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except:
        continue



# Load old data (if file exists)
try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []   # file didn't exist → start fresh

# Append new articles
updated_data = old_data + final_output

unique = []
links = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in links:
        links.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print("Updated json with", len(final_output), "new articles.")
final_output[0:3]
# Out:
# https://indianexpress.com/section/world/?ref=l1_section
# Updated json with 0 new articles.
# []

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup

index = "business"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]

print(url)

# Load all headers from CSV
header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)

response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

# BUSINESS: all articles inside <div class="o-opin-article">
for art in soup.find_all("div", class_="o-opin-article"):
    try:
        # AUTHOR + DATE
        writer = art.select_one("div.news-writer-name")
        author = writer.select_one("a").text.strip() if writer and writer.select_one("a") else "N/A"
        date = writer.select_one("span.opinion-date").text.strip() if writer and writer.select_one("span.opinion-date") else "N/A"

        # HEADLINE (CSS SELECTOR FIX)
        a = art.select_one("a.opinion-news-title")
        headline = a.text.strip() if a else "N/A"
        link = a["href"] if a else "N/A"

        # SUMMARY
        summary_block = art.select_one("div.opinion-news-para")
        summary = summary_block.text.strip() if summary_block else "N/A"

        # IMAGE
        img_tag = art.select_one("div.opinion-news-figure img")
        img_url = img_tag.get("data-src") or img_tag.get("src") if img_tag else "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": author,
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": summary
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except Exception as e:
        print("Error:", e)
        continue


try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []

updated_data = old_data + final_output

unique = []
seen = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in seen:
        seen.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print("Updated json with", len(final_output), "new business articles.")
final_output[:3]
# Out:
# https://indianexpress.com/section/business/?ref=l1_section
# Updated json with 25 new business articles.
# [{'primary_article': {'headline': 'India Inc pins hopes on implementation of labour codes by states for effective transition',
#    'author': 'Ravi Dutta Mishra',
#    'article_link': 'https://indianexpress.com/article/business/india-inc-pins-hopes-on-implementation-of-labour-codes-by-states-for-effective-transition-10379196/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/EMPL14id.jpeg?w=300',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 21, 2025',
#    'summary': "India's largest IT industry association Nasscom said the government’s notification bringing key provisions of the labour codes into effect marks a significant moment in India’s labour reform journey."},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Centre may widen ‘obscene’ content net to ‘half truths,’ criticism of social, public figures',
#    'author': 'Soumyarendra Barik',
#    'article_link': 'https://indianexpress.com/article/business/centre-obscene-content-net-half-truths-criticism-social-public-figures-10379027/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/netflix-file-photo.jpg?w=300',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 21, 2025',
#    'summary': 'These changes are being considered for part III of the IT Rules, which covers over-the-top (OTT) video platforms like Netflix, Prime Video and Disney+ Hotstar and digital news publications.'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Rupee falls to record low of 89.41: Here’s why',
#    'author': 'Hitesh Vyas',
#    'article_link': 'https://indianexpress.com/article/business/rupee-falls-to-record-low-of-89-41-heres-why-10378798/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/rupee_7e42de.jpg?w=300',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 21, 2025',
#    'summary': 'The rupee plunged 70 paise, or 0.79 per cent, to close at 89.41, marking the biggest single-day fall since May 8, compared to the previous close of 88.71.'},
#   'related_articles': [],
#   'total_related_articles': 0}]

# %%
import json, csv, random, requests
from bs4 import BeautifulSoup

index = "technology"
url = CATEGORY_URLS[index]
json_path = JSON_NAMES[index]
print(url)

# Load headers
header_list = []
with open("headers.csv", "r", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        header_list.append({
            "User-Agent": row["User-Agent"],
            "Accept-Language": row["Accept-Language"]
        })

def get_random_header():
    return random.choice(header_list)

response = requests.get(url, headers=get_random_header())
soup = BeautifulSoup(response.text, "html.parser")

final_output = []

# MAIN: all technology news rows
for art in soup.find_all("div", class_="area-row"):

    try:

        img_tag = art.select_one("figure.thumb-wrap img")
        img_url = (
            img_tag.get("data-src") or 
            img_tag.get("src") 
        ) if img_tag else "N/A"


        category_tag = art.select_one("span.category")
        category = category_tag.text.strip() if category_tag else "N/A"

        date_tag = art.select_one("time.time-stamp")
        date = date_tag.text.strip() if date_tag else "N/A"


        h = art.select_one("h3.list-heading")
        headline = h.text.strip() if h else "N/A"

        a_tag = art.find("a", href=True)
        link = a_tag["href"] if a_tag else "N/A"
        
        summary = "N/A"

        final_output.append({
            "primary_article": {
                "headline": headline,
                "author": "N/A",
                "article_link": link,
                "featured_image": img_url,
                "source_logo": "N/A",
                "source_name": "IndianExpress",
                "publish_date": date,
                "summary": summary,
                "category": category
            },
            "related_articles": [],
            "total_related_articles": 0
        })

    except Exception as e:
        print("Error:", e)
        continue


# -------------------------------
# UPDATE JSON FILE
# -------------------------------
try:
    with open(json_path, "r", encoding="utf-8") as f:
        old_data = json.load(f)
except:
    old_data = []

updated_data = old_data + final_output

unique = []
seen = set()

for article in updated_data:
    link = article["primary_article"]["article_link"]
    if link not in seen:
        seen.add(link)
        unique.append(article)

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(unique, f, indent=4, ensure_ascii=False)

print(f"Updated {json_path} with {len(final_output)} new articles.")
print(f"Total unique articles: {len(unique)}")

final_output[:3]
# Out:
# https://indianexpress.com/section/technology/?ref=l1_section
# Updated technology_news.json with 25 new articles.
# Total unique articles: 118
# [{'primary_article': {'headline': 'Gemini 3 vs Gemini 3 Pro vs Gemini 3 DeepThink: A quick guide to Google’s latest AI models',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/section/technology/artificial-intelligence/',
#    'featured_image': 'https://images.indianexpress.com/2025/11/Tech-feature-images159.jpg?w=320',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 23, 2025',
#    'summary': 'N/A',
#    'category': 'Artificial Intelligence'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'Google targets 1000x compute growth, aims to double capacity every 6 months: Report',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/section/technology/artificial-intelligence/',
#    'featured_image': 'https://images.indianexpress.com/2025/05/Sundar-Pichai.jpg?w=320',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 23, 2025',
#    'summary': 'N/A',
#    'category': 'Artificial Intelligence'},
#   'related_articles': [],
#   'total_related_articles': 0},
#  {'primary_article': {'headline': 'The fate of Google’s ad tech monopoly is now in a judge’s hands',
#    'author': 'N/A',
#    'article_link': 'https://indianexpress.com/section/technology/tech-news-technology/',
#    'featured_image': 'https://images.indianexpress.com/2025/05/Google-Reuters.jpg?w=320',
#    'source_logo': 'N/A',
#    'source_name': 'IndianExpress',
#    'publish_date': 'Nov 23, 2025',
#    'summary': 'N/A',
#    'category': 'Tech'},
#   'related_articles': [],
#   'total_related_articles': 0}]
