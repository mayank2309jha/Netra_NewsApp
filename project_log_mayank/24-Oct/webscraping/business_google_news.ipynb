# %% [markdown]
# ## 1. Get random headers out of a csv list of 20 random headers

# %%
import csv
import requests
import random

# Load headers from CSV
headers_list = []
with open('headers.csv', 'r', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Remove empty values to avoid sending None/empty headers
        headers = {k: v for k, v in row.items() if v}
        headers_list.append(headers)

# %% [markdown]
# ## 2. Get soup content

# %%
from bs4 import BeautifulSoup
import time
url = "https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRGx6TVdZU0JXVnVMVWRDR2dKSlRpZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
headers = random.choice(headers_list)
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# ## 3. Get content in cards

# %%
cards = soup.find_all("c-wiz", {
    "jsrenderer": "ARwRbe",
    "jsmodel": "hc6Ubd",
    "class": "PO9Zff Ccj79 kUVvS"
})

print(f"Found {len(cards)} news cards.\n")

news_cards_html = [str(card) for card in cards]

print(news_cards_html[0][:100], "...")
# Out:
# Found 71 news cards.
#
# <c-wiz c-wiz="" class="PO9Zff Ccj79 kUVvS" data-node-index="1;0" data-p="%.@.]" jsdata="deferred-i18 ...

# %% [markdown]
# ## 4. Remove the outer covering and getting the useful HTML within

# %%
inner_divs = []

for card in cards:
    # find the inner <c-wiz> inside each outer c-wiz
    inner_cwiz = card.find("c-wiz", recursive=True)
    if inner_cwiz:
        # find the first <div> inside the <div> of the inner c-wiz
        # structure: <c-wiz> -> <div> -> <div>
        first_div = inner_cwiz.find("div", recursive=False)
        if first_div:
            second_div = first_div.find("div", recursive=False)
            if second_div:
                inner_divs.append(second_div)

print(f"Extracted {len(inner_divs)} inner divs.")

# Convert them to HTML strings if needed
inner_divs_html = [str(div) for div in inner_divs]

# Example: print one
print(inner_divs_html[0][:500], "...")
# Out:
# Extracted 69 inner divs.
# <div class="VGgDjd"><a class="taS2Yb Mi07Bb hpDt6e XPO28d" href="https://www.google.com/search?q=INDEXBOM+SENSEX&amp;hl=en-GB&amp;source=news" jslog="181750; track:click" target="_blank"><svg class="JMZsIc NMm5M" focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24"><path d="M4 12l1.41 1.41L11 7.83V20h2V7.83l5.58 5.59L20 12l-8-8-8 8z"></path></svg><div class="IWF7Od"><div class="xWTvcb">Sensex</div><div class="vvivme">84,556.40</div></div><div class="IWF7Od"><div class ...

# %% [markdown]
# ## 5. This is function which takes a card's HTML and returns a dictionary of dictionaries which is arranged like the DOM's structure

# %%
def element_to_dom(element):
    """Recursively convert a BeautifulSoup element to a nested dictionary structure."""
    dom = {}

    for child in element.children:
        # Skip text nodes that are just whitespace
        if child.name is None:
            text = child.strip()
            if text:
                dom["text"] = text
            continue

        tag = child.name

        # Determine value based on tag type
        if tag == "a":
            value = child.get("href")
        elif tag == "img":
            value = child.get("src")
        elif tag == "svg":
            value = str(child)
        elif tag in ["h1", "h2", "h3", "h4", "h5", "h6", "p", "span", "time", "button"]:
            value = child.decode_contents().strip()
        else:
            # If element has nested tags, recurse
            nested = element_to_dom(child)
            value = nested if nested else child.decode_contents().strip()

        # Handle multiple same-tag children by converting value into a list
        if tag in dom:
            if isinstance(dom[tag], list):
                dom[tag].append(value)
            else:
                dom[tag] = [dom[tag], value]
        else:
            dom[tag] = value

    return dom


# Assuming inner_divs_html is already available
dom_structures = []

for html in inner_divs_html:
    soup = BeautifulSoup(html, "html.parser")
    dom_dict = element_to_dom(soup)
    dom_structures.append(dom_dict)

# %% [markdown]
# ## 6. To better view the structure of a single card's HTML

# %%
import json
print(json.dumps(dom_structures, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "div": {
#       "a": [
#         "https://www.google.com/search?q=INDEXBOM+SENSEX&hl=en-GB&source=news",
#         "https://www.google.com/search?q=INDEXNSE+NIFTY_50&hl=en-GB&source=news",
#         "https://www.google.com/search?q=INDEXNIKKEI+NI225&hl=en-GB&source=news",
#         "https://www.google.com/search?q=SHA+000001&hl=en-GB&source=news"
#       ]
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "Mint"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Crypto-exchange Binance founder Changpeng Zhao receives pardon from Trump amid money laundering admission\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i22\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i22\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "3 hours ago",
#             "hr": "",
#             "div": {
#               "span": "By Ravi Hari"
#             }
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iK0NnNTNNMEpTWkVKMVUxVkhXRms0VFJDZkF4ampCU2dLTWdhcGRZck5zUVU=-w280-h168-p-df"
#         },
#         "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": "./read/CBMiWkFVX3lxTE5McDRBaTdEUXNKVmhRbmRxU2szYzN5MDk0MHpPOGZhdGFmWnpxRGR5TDFGNjFWa252WE55anBmclpnbWx0SjNfbWVVVUUtME42SV9nN05nY0RoUQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.bbc.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "BBC"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - President Trump pardons Binance founder Changpeng Zhao\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i23\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i23\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "1 hour ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Liv Mcmahon"
#                 }
#               }
#             ],
#             "a": "./read/CBMiWkFVX3lxTE5McDRBaTdEUXNKVmhRbmRxU2szYzN5MDk0MHpPOGZhdGFmWnpxRGR5TDFGNjFWa252WE55anBmclpnbWx0SjNfbWVVVUUtME42SV9nN05nY0RoUQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "./read/CBMijwFBVV95cUxNTUdoaHluZE9IUU5YZDl3c3pReWVIazBIeDE0a0k4NVhPQkR3QzJkRFBhMl9ldFJ2TU5SenBrWFZnQXVkcXdvWjh3aEhoVThfSmQyTEFpelliVmZEamE4TFd2Y19ZMVd6VnlqcmQtTjdhZVJGOTFpWE9GZERTZkxtVFhLM0VYaV95alhXV09ROA?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.theguardian.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "The Guardian"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Trump pardons founder of Binance, world’s largest crypto exchange\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i24\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i24\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "3 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Nick Robins"
#                 }
#               }
#             ],
#             "a": "./read/CBMijwFBVV95cUxNTUdoaHluZE9IUU5YZDl3c3pReWVIazBIeDE0a0k4NVhPQkR3QzJkRFBhMl9ldFJ2TU5SenBrWFZnQXVkcXdvWjh3aEhoVThfSmQyTEFpelliVmZEamE4TFd2Y19ZMVd6VnlqcmQtTjdhZVJGOTFpWE9GZERTZkxtVFhLM0VYaV95alhXV09ROA?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "./read/CBMid0FVX3lxTE9PeHBpb284bnp1cXpXVXJBN2ZwdDVWdW1IMkJWT2NEYnRIRFNJbkU0d0ZxZnBxV1h4Uk41d2tBN1BsRlRMaUdGN2NoQzBHem1yYmE3XzBRS1NwNWlmSGRoQVpDUU10OVFSQlNQckp4ektfMTRiNnNJ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.cnn.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "CNN"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Trump pardons Binance founder Changpeng Zhao\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i25\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i25\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Alayna Treene"
#                 }
#               }
#             ],
#             "a": "./read/CBMid0FVX3lxTE9PeHBpb284bnp1cXpXVXJBN2ZwdDVWdW1IMkJWT2NEYnRIRFNJbkU0d0ZxZnBxV1h4Uk41d2tBN1BsRlRMaUdGN2NoQzBHem1yYmE3XzBRS1NwNWlmSGRoQVpDUU10OVFSQlNQckp4ektfMTRiNnNJ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2p6NHVqckR4R2p5SjdIbGtZVE1pZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.reuters.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "Reuters"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Apple loses landmark UK lawsuit over app store commissions\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i28\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i28\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "1 hour ago",
#             "hr": "",
#             "div": {
#               "span": "By Sam Tobin"
#             }
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iK0NnNDBTbWszVlRoeVprdHlSelp3VFJERUF4aW1CU2dLTWdhbGRJcXRRUVU=-w280-h168-p-df"
#         },
#         "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": "./read/CBMinAFBVV95cUxQMEF6cVduVUl2UGZDcWpPSkpYbVgwY0UxalBOOUd1OUlWTDRQMGlPb2l4R0VpSXY3cDc3X1BEX0F3djBzeGpiR25xZklvWXhHdjVGcHlZLXp2c0dybkNoOEpHR1k0QlM4b2U4N2xWQnNqb2FLMk1na2FWR2lvbGpJLWJ2NURvbzJ4VmZGVVJxTFVwVkMyUVBqT3pXalE?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ndtv.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "NDTV"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Apple Loses $2 Billion UK Lawsuit Over App Store Monopoly\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i29\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i29\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "34 minutes ago"
#               }
#             ],
#             "a": "./read/CBMinAFBVV95cUxQMEF6cVduVUl2UGZDcWpPSkpYbVgwY0UxalBOOUd1OUlWTDRQMGlPb2l4R0VpSXY3cDc3X1BEX0F3djBzeGpiR25xZklvWXhHdjVGcHlZLXp2c0dybkNoOEpHR1k0QlM4b2U4N2xWQnNqb2FLMk1na2FWR2lvbGpJLWJ2NURvbzJ4VmZGVVJxTFVwVkMyUVBqT3pXalE?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Mint"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Apple loses UK lawsuit over unfair 30% App Store commissions: What we know\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i30\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i30\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "3 hours ago"
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.indiatoday.in&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "India Today"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Apple loses UK lawsuit over App Store’s unfair 30% developer commissions\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i31\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i31\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Sonali Verma"
#                 }
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2lBamV2ckR4R3RTeDRFOGtlRlJpZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.thehindu.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "The Hindu"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - ‘Trust’ issue among Tata trustees\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i34\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i34\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "18 hours ago",
#             "hr": "",
#             "div": {
#               "span": "By Raghuvir Srinivasan"
#             }
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iK0NnNVNUbE5HVWxBeFUwVnZUWFpSVFJDZkF4ampCU2dLTWdhcE5aak5IUWs=-w280-h168-p-df"
#         },
#         "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.business-standard.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Business Standard"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Tata Trusts moves proposal to reappoint Mehli Mistry as lifetime trustee\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i35\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i35\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "5 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Rahul Goreja"
#                 }
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "./read/CBMirwFBVV95cUxQTG0xSTZnUHJ5NEVCM3ZvLUczTG5YbThBM0tEdFpyaW41U295bzZXZlBEUkdjUUhGQ2hwTEtPelVFZFUzbmZ5UVFmaTlFME5WcDhtMWRuSmNHOFpCVzBuR0RuZ0V4R0trUGg2dHBYdmJJQUVUYmRXSlVDZTROLWRPeUM0WE5JQnF1MUc4SGxyTWM2NVJxbFZrRHg3RUt0dzhubEFoZ09IeVRGS01XeUFF?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Mint"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Tata Trust saga: Srinivasan permanent trusteeship a formality, say four trustees; want similar renewals for all\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i36\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i36\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "10 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Satish John and Varun Sood"
#                 }
#               }
#             ],
#             "a": "./read/CBMirwFBVV95cUxQTG0xSTZnUHJ5NEVCM3ZvLUczTG5YbThBM0tEdFpyaW41U295bzZXZlBEUkdjUUhGQ2hwTEtPelVFZFUzbmZ5UVFmaTlFME5WcDhtMWRuSmNHOFpCVzBuR0RuZ0V4R0trUGg2dHBYdmJJQUVUYmRXSlVDZTROLWRPeUM0WE5JQnF1MUc4SGxyTWM2NVJxbFZrRHg3RUt0dzhubEFoZ09IeVRGS01XeUFF?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn3.gstatic.com/faviconV2?url=https://m.economictimes.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "The Economic Times"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Mehli Mistry sets rare condition for trustee renewal at Tata Trusts amid simmering differences\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i37\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i37\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "18 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Kala Vijayraghavan"
#                 }
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2lRNF9Ua0R4RjJCTnNVaUVnSG1DZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.business-standard.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "Business Standard"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Jaguar Land Rover August hack cost UK economy $2.5 billion: Report\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i40\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i40\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "2 days ago"
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iK0NnNXJSMjlKYkZSRWNVZDNUM2xHVFJDUUJCakZCQ2dLTWdZaHBZYk1UUU0=-w280-h168-p-df"
#         },
#         "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.thehindu.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "The Hindu"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Tata Motors JLR cyber-hack worst in U.K. history that hit 5,000 firms, research finds\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i41\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i41\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "12 hours ago"
#               }
#             ],
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ndtv.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "NDTV"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Jaguar Land Rover Hack Dealt $2.5-Billion Blow To British Economy: Report\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i42\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i42\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 days ago"
#               }
#             ],
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Mint"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - JLR may have suffered a £540 million hit due to the cyberattack\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i43\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i43\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 days ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Ayaan Kartik"
#                 }
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2pUaF9Qb0R4SHFaR1gtNXpDdFRDZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn0.gstatic.com/faviconV2?url=https://upstox.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "Upstox"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - NIFTY50 hits 26,100, SENSEX jumps 705 pts in noon deals; Infosys, HUL, RIL, BEL among buzzing stocks\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i46\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i46\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "11 hours ago",
#             "hr": "",
#             "div": {
#               "span": "By Ahana Chatterjee"
#             }
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iL0NnNXNka2x6UTBkM1JtWkNMWEkwVFJEZ0F4aUFCU2dLTWdrZElZN3NNV1l0aGdJ=-w280-h168-p-df"
#         },
#         "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn3.gstatic.com/faviconV2?url=https://m.economictimes.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "The Economic Times"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Midcaps take the lead as Nifty nears record high; Rahul Sharma sees sector rotation ahead\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i47\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i47\" role=\"tooltip\">More</div>"
#                           },
# ...
#                     "div": {
#                       "div": {
#                         "text": "ET BrandEquity"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Netflix blames tax dispute in Brazil for rare quarterly earnings letdown\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i425\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i425\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 days ago"
#               }
#             ],
#             "a": "....?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Mint"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Netflix shares fall 6.5% after missing Q3 earnings estimates - what led to the drop?\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i426\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i426\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "2 days ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Riya Alex"
#                 }
#               }
#             ],
#             "a": ".?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2l3Z2JmbER4SDhGVmdSODcxRzRTZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   },
#   {
#     "div": {
#       "article": {
#         "div": [
#           {
#             "a": "./read/CBMie0FVX3lxTE9BZTlYWURCOUYxSDFKNHp0ZVhVQzl4V0JRVWlnbldxS2hsUXJaeG45eG1fRUp5Zzl3MVI2Z003c2xrbWNrSTRvckpXU29SN3BncklGUEhMWnFHRVJHelVNUkVZbzE2bTdoNkwyZnp4dS05bmRLUDZKaFhJaw?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "img": "https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.nestle.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                 "div": {
#                   "div": {
#                     "text": "Nestlé"
#                   }
#                 }
#               },
#               {
#                 "div": {
#                   "div": {
#                     "div": [
#                       {
#                         "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Nestlé increases speed and consumer focus with landmark digital core upgrade that enables AI and automation at scale\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i429\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i429\" role=\"tooltip\">More</div>"
#                       },
#                       ""
#                     ]
#                   }
#                 }
#               }
#             ]
#           },
#           {
#             "time": "11 hours ago"
#           }
#         ],
#         "figure": {
#           "img": "/api/attachments/CC8iK0NnNVBRVmh5Y0RsRlFVTlBiMHhUVFJDQkF4aWRCaWdLTWdhNUlZelRtQWs=-w280-h168-p-df"
#         },
#         "a": "./read/CBMie0FVX3lxTE9BZTlYWURCOUYxSDFKNHp0ZVhVQzl4V0JRVWlnbldxS2hsUXJaeG45eG1fRUp5Zzl3MVI2Z003c2xrbWNrSTRvckpXU29SN3BncklGUEhMWnFHRVJHelVNUkVZbzE2bTdoNkwyZnp4dS05bmRLUDZKaFhJaw?hl=en-IN&gl=IN&ceid=IN%3Aen"
#       },
#       "div": {
#         "article": [
#           {
#             "div": [
#               {
#                 "a": "./read/CBMimAFBVV95cUxPQkN1T2k2NGFLdVM2Q0FUZkNOWGU5VmRuaUlzWUFtZDI1QkJrVjFCTHZRTmJNY2EzQjFZejdEZjliNUVnNVhUUXExSmxCTjk3ZFZTbkxzckZXUFhQVkJadF9JQmFOcUNONnUzRVM1QjBMZWJQY28wZkNBbWZZbG02Yk5DZllqNEw4aU9LOHlySGpzbEVmRHNjWA?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn3.gstatic.com/faviconV2?url=https://news.sap.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "SAP News Center"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - Nestlé Sweetens Its Digital Future with an Upgrade to SAP S/4HANA Cloud Private Edition\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i430\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i430\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "10 hours ago"
#               }
#             ],
#             "a": "./read/CBMimAFBVV95cUxPQkN1T2k2NGFLdVM2Q0FUZkNOWGU5VmRuaUlzWUFtZDI1QkJrVjFCTHZRTmJNY2EzQjFZejdEZjliNUVnNVhUUXExSmxCTjk3ZFZTbkxzckZXUFhQVkJadF9JQmFOcUNONnUzRVM1QjBMZWJQY28wZkNBbWZZbG02Yk5DZllqNEw4aU9LOHlySGpzbEVmRHNjWA?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "./read/CBMilwFBVV95cUxPNWFQUGcwbE9lcy1LbDgtTHFHMHJJVlI2NS1lQzRkcE1kNXNKb1JkdmZJbUtNeXNZWDg2V3lhNnZ6YUJmMEJQYUhMZS05SG5kdmU5c1cwR3JVLWJMcmdMNjhyaEtaMl9JWWVtV3RLMXZKOEZZZ1hscl9KTUl3MGRCYWlKc2Q1QXlvZVdNYk9yd2thVzFVdkY4?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn1.gstatic.com/faviconV2?url=https://technologymagazine.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "Technology Magazine"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - How Nestlé Uses SAP S/4HANA Cloud to Scale AI Operations\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i431\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i431\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "7 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Marcus Law"
#                 }
#               }
#             ],
#             "a": "./read/CBMilwFBVV95cUxPNWFQUGcwbE9lcy1LbDgtTHFHMHJJVlI2NS1lQzRkcE1kNXNKb1JkdmZJbUtNeXNZWDg2V3lhNnZ6YUJmMEJQYUhMZS05SG5kdmU5c1cwR3JVLWJMcmdMNjhyaEtaMl9JWWVtV3RLMXZKOEZZZ1hscl9KTUl3MGRCYWlKc2Q1QXlvZVdNYk9yd2thVzFVdkY4?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           },
#           {
#             "div": [
#               {
#                 "a": "./read/CBMiowFBVV95cUxQRV95cUpIRzB2MHNpN3owQjFjTnhCdGhtMXlGZW4tWGJvSDJsdklaQ0UzcmtTT0plX2ZCV2xiS1Fjemh2Q1hSQWxrY3FSLV93cjRDU0pNaFk4emNaZ2wwWWtkMWhTMzMyV1FOUGZaV0RCMW0yNnNFa1RiTmUyV3lXOV9QQ19qa3NUZkRxVm1KSG9wSGkxS0VWc3R1ZDFuNUFDNVNz?hl=en-IN&gl=IN&ceid=IN%3Aen"
#               },
#               {
#                 "div": [
#                   {
#                     "img": "https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.foodingredientsfirst.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL",
#                     "div": {
#                       "div": {
#                         "text": "foodingredientsfirst.com"
#                       }
#                     }
#                   },
#                   {
#                     "div": {
#                       "div": {
#                         "div": [
#                           {
#                             "span": "<button aria-expanded=\"false\" aria-haspopup=\"menu\" aria-label=\"More - AI and automation: Nestlé enhances innovation and speed in major digital upgrade\" class=\"VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud\" data-idom-class=\"yHy1rc eT1oJ mN1ivc hUJSud\" data-n-tid=\"27\" data-tooltip-enabled=\"true\" data-tooltip-id=\"tt-i432\" jsaction=\"click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;\" jscontroller=\"soHxf\"><div class=\"VfPpkd-Bz112c-Jh9lGc\" jsname=\"s3Eaab\"></div><div class=\"VfPpkd-Bz112c-J1Ukfc-LhBDec\"></div><span aria-hidden=\"true\" class=\"notranslate VfPpkd-kBDsod\"><svg class=\"NMm5M\" focusable=\"false\" height=\"24\" viewbox=\"0 0 24 24\" width=\"24\"><path d=\"M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z\"></path></svg></span></button><div aria-hidden=\"true\" class=\"EY8ABd-OWXEXe-TAWMXe\" id=\"tt-i432\" role=\"tooltip\">More</div>"
#                           },
#                           ""
#                         ]
#                       }
#                     }
#                   }
#                 ]
#               },
#               {
#                 "time": "4 hours ago",
#                 "hr": "",
#                 "div": {
#                   "span": "By Gaynor Selby"
#                 }
#               }
#             ],
#             "a": "./read/CBMiowFBVV95cUxQRV95cUpIRzB2MHNpN3owQjFjTnhCdGhtMXlGZW4tWGJvSDJsdklaQ0UzcmtTT0plX2ZCV2xiS1Fjemh2Q1hSQWxrY3FSLV93cjRDU0pNaFk4emNaZ2wwWWtkMWhTMzMyV1FOUGZaV0RCMW0yNnNFa1RiTmUyV3lXOV9QQ19qa3NUZkRxVm1KSG9wSGkxS0VWc3R1ZDFuNUFDNVNz?hl=en-IN&gl=IN&ceid=IN%3Aen"
#           }
#         ],
#         "div": {
#           "a": "./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2pHX0xyckR4R00yQ1lETjN2V3lpZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen"
#         }
#       }
#     }
#   }
# ]

# %% [markdown]
# ## Just for viewing purpose, ignore and move on

# %%
dom_structures[1]["div"]["article"]
# Out:
# {'div': [{'a': '....?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#   {'div': [{'img': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#      'div': {'div': {'text': 'Mint'}}},
#     {'div': {'div': {'div': [{'span': '<button aria-expanded="false" aria-haspopup="menu" aria-label="More - Crypto-exchange Binance founder Changpeng Zhao receives pardon from Trump amid money laundering admission" class="VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud" data-idom-class="yHy1rc eT1oJ mN1ivc hUJSud" data-n-tid="27" data-tooltip-enabled="true" data-tooltip-id="tt-i22" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;" jscontroller="soHxf"><div class="VfPpkd-Bz112c-Jh9lGc" jsname="s3Eaab"></div><div class="VfPpkd-Bz112c-J1Ukfc-LhBDec"></div><span aria-hidden="true" class="notranslate VfPpkd-kBDsod"><svg class="NMm5M" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></span></button><div aria-hidden="true" class="EY8ABd-OWXEXe-TAWMXe" id="tt-i22" role="tooltip">More</div>'},
#         '']}}}]},
#   {'time': '3 hours ago', 'hr': '', 'div': {'span': 'By Ravi Hari'}}],
#  'figure': {'img': '/api/attachments/CC8iK0NnNTNNMEpTWkVKMVUxVkhXRms0VFJDZkF4ampCU2dLTWdhcGRZck5zUVU=-w280-h168-p-df'},
#  'a': '....?hl=en-IN&gl=IN&ceid=IN%3Aen'}

# %% [markdown]
# ## just for viewing purpose, ignore and move on

# %%
dom_structures[1]["div"]["div"]
# Out:
# {'article': [{'div': [{'a': './read/CBMiWkFVX3lxTE5McDRBaTdEUXNKVmhRbmRxU2szYzN5MDk0MHpPOGZhdGFmWnpxRGR5TDFGNjFWa252WE55anBmclpnbWx0SjNfbWVVVUUtME42SV9nN05nY0RoUQ?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#     {'div': [{'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.bbc.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#        'div': {'div': {'text': 'BBC'}}},
#       {'div': {'div': {'div': [{'span': '<button aria-expanded="false" aria-haspopup="menu" aria-label="More - President Trump pardons Binance founder Changpeng Zhao" class="VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud" data-idom-class="yHy1rc eT1oJ mN1ivc hUJSud" data-n-tid="27" data-tooltip-enabled="true" data-tooltip-id="tt-i23" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;" jscontroller="soHxf"><div class="VfPpkd-Bz112c-Jh9lGc" jsname="s3Eaab"></div><div class="VfPpkd-Bz112c-J1Ukfc-LhBDec"></div><span aria-hidden="true" class="notranslate VfPpkd-kBDsod"><svg class="NMm5M" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></span></button><div aria-hidden="true" class="EY8ABd-OWXEXe-TAWMXe" id="tt-i23" role="tooltip">More</div>'},
#           '']}}}]},
#     {'time': '1 hour ago', 'hr': '', 'div': {'span': 'By Liv Mcmahon'}}],
#    'a': './read/CBMiWkFVX3lxTE5McDRBaTdEUXNKVmhRbmRxU2szYzN5MDk0MHpPOGZhdGFmWnpxRGR5TDFGNjFWa252WE55anBmclpnbWx0SjNfbWVVVUUtME42SV9nN05nY0RoUQ?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#   {'div': [{'a': './read/CBMijwFBVV95cUxNTUdoaHluZE9IUU5YZDl3c3pReWVIazBIeDE0a0k4NVhPQkR3QzJkRFBhMl9ldFJ2TU5SenBrWFZnQXVkcXdvWjh3aEhoVThfSmQyTEFpelliVmZEamE4TFd2Y19ZMVd6VnlqcmQtTjdhZVJGOTFpWE9GZERTZkxtVFhLM0VYaV95alhXV09ROA?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#     {'div': [{'img': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.theguardian.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#        'div': {'div': {'text': 'The Guardian'}}},
#       {'div': {'div': {'div': [{'span': '<button aria-expanded="false" aria-haspopup="menu" aria-label="More - Trump pardons founder of Binance, world’s largest crypto exchange" class="VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud" data-idom-class="yHy1rc eT1oJ mN1ivc hUJSud" data-n-tid="27" data-tooltip-enabled="true" data-tooltip-id="tt-i24" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;" jscontroller="soHxf"><div class="VfPpkd-Bz112c-Jh9lGc" jsname="s3Eaab"></div><div class="VfPpkd-Bz112c-J1Ukfc-LhBDec"></div><span aria-hidden="true" class="notranslate VfPpkd-kBDsod"><svg class="NMm5M" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></span></button><div aria-hidden="true" class="EY8ABd-OWXEXe-TAWMXe" id="tt-i24" role="tooltip">More</div>'},
#           '']}}}]},
#     {'time': '3 hours ago', 'hr': '', 'div': {'span': 'By Nick Robins'}}],
#    'a': './read/CBMijwFBVV95cUxNTUdoaHluZE9IUU5YZDl3c3pReWVIazBIeDE0a0k4NVhPQkR3QzJkRFBhMl9ldFJ2TU5SenBrWFZnQXVkcXdvWjh3aEhoVThfSmQyTEFpelliVmZEamE4TFd2Y19ZMVd6VnlqcmQtTjdhZVJGOTFpWE9GZERTZkxtVFhLM0VYaV95alhXV09ROA?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#   {'div': [{'a': './read/CBMid0FVX3lxTE9PeHBpb284bnp1cXpXVXJBN2ZwdDVWdW1IMkJWT2NEYnRIRFNJbkU0d0ZxZnBxV1h4Uk41d2tBN1BsRlRMaUdGN2NoQzBHem1yYmE3XzBRS1NwNWlmSGRoQVpDUU10OVFSQlNQckp4ektfMTRiNnNJ?hl=en-IN&gl=IN&ceid=IN%3Aen'},
#     {'div': [{'img': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.cnn.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#        'div': {'div': {'text': 'CNN'}}},
#       {'div': {'div': {'div': [{'span': '<button aria-expanded="false" aria-haspopup="menu" aria-label="More - Trump pardons Binance founder Changpeng Zhao" class="VfPpkd-Bz112c-LgbsSe yHy1rc eT1oJ mN1ivc hUJSud" data-idom-class="yHy1rc eT1oJ mN1ivc hUJSud" data-n-tid="27" data-tooltip-enabled="true" data-tooltip-id="tt-i25" jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e; contextmenu:mg9Pef;mlnRJb:fLiPzd;" jscontroller="soHxf"><div class="VfPpkd-Bz112c-Jh9lGc" jsname="s3Eaab"></div><div class="VfPpkd-Bz112c-J1Ukfc-LhBDec"></div><span aria-hidden="true" class="notranslate VfPpkd-kBDsod"><svg class="NMm5M" focusable="false" height="24" viewbox="0 0 24 24" width="24"><path d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></span></button><div aria-hidden="true" class="EY8ABd-OWXEXe-TAWMXe" id="tt-i25" role="tooltip">More</div>'},
#           '']}}}]},
#     {'time': '2 hours ago', 'hr': '', 'div': {'span': 'By Alayna Treene'}}],
#    'a': './read/CBMid0FVX3lxTE9PeHBpb284bnp1cXpXVXJBN2ZwdDVWdW1IMkJWT2NEYnRIRFNJbkU0d0ZxZnBxV1h4Uk41d2tBN1BsRlRMaUdGN2NoQzBHem1yYmE3XzBRS1NwNWlmSGRoQVpDUU10OVFSQlNQckp4ektfMTRiNnNJ?hl=en-IN&gl=IN&ceid=IN%3Aen'}],
#  'div': {'a': './stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2p6NHVqckR4R2p5SjdIbGtZVE1pZ0FQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen'}}

# %% [markdown]
# ## The articles to the links are given in relative form, so to open them we have to add a prefix as shown

# %%
url_to_search = "https://news.google.com" + dom_structures[1]["div"]["article"]["div"][0]["a"][1:]
url_to_search
# Out:
# 'https://news.google....?hl=en-IN&gl=IN&ceid=IN%3Aen'

# %%
import webbrowser
url_to_search

webbrowser.open_new_tab(url_to_search)
# Out:
# True

# %% [markdown]
# ## 7. This function takes a dictionary of dictionaries and returns the data in more usable format which will be the format of the json

# %%
from datetime import datetime

def get_news_data(dom_structure):
    """
    Extracts structured news data from a single dom_structure[i] element.
    Returns a dictionary containing:
      - primary_article (headline, link, author, etc.)
      - related_articles (list of dictionaries)
      - total_related_articles (count)
    """
    BASE_URL = "https://news.google.com"
    today_date = datetime.now().strftime("%d-%m-%Y")  # current date in dd-mm-yyyy

    # --- PRIMARY ARTICLE ---
    article = dom_structure.get("div", {}).get("article", {})
    news_data = {
        'headline': article.get('div', [])[2].get('div', {}).get('span', 'N/A')
        if isinstance(article.get('div', []), list) and len(article.get('div', [])) > 2 else 'N/A',

        'author': article.get('div', [])[2].get('div', {}).get('span', 'N/A')
        if isinstance(article.get('div', []), list) and len(article.get('div', [])) > 2 else 'N/A',

        'article_link': (
            BASE_URL + article.get('a', '')
            if article.get('a') not in (None, 'N/A') else 'N/A'
        ),

        'featured_image': article.get('figure', {}).get('img', 'N/A'),

        'source_logo': (
            article.get('div', [])[1].get('div', [])[0].get('img', 'N/A')
            if isinstance(article.get('div', []), list)
            and len(article.get('div', [])) > 1
            and isinstance(article.get('div', [])[1].get('div', []), list)
            else 'N/A'
        ),

        'source_name': (
            article.get('div', [])[1]
            .get('div', [])[0]
            .get('div', {})
            .get('div', {})
            .get('text', 'N/A')
            if isinstance(article.get('div', []), list)
            and len(article.get('div', [])) > 1
            and isinstance(article.get('div', [])[1].get('div', []), list)
            else 'N/A'
        ),

        # --- NEW FIELD ---
        'publish_date': today_date
    }

    # --- RELATED ARTICLES ---
    related_articles = []
    possible_related = dom_structure.get("div", {}).get("div", {}).get("article", [])

    if isinstance(possible_related, list):
        for article in possible_related:
            if not isinstance(article, dict):
                continue

            divs = article.get('div', [])
            if not isinstance(divs, list) or len(divs) < 3:
                continue

            raw_link = article.get('a', '')
            full_link = BASE_URL + raw_link if raw_link not in (None, 'N/A') else 'N/A'

            article_data = {
                'headline': divs[2].get('div', {}).get('span', 'N/A'),
                'author': divs[2].get('div', {}).get('span', 'N/A'),
                'article_link': full_link,
                'source_logo': (
                    divs[1].get('div', [])[0].get('img', 'N/A')
                    if len(divs) > 1 and isinstance(divs[1].get('div', []), list)
                    else 'N/A'
                ),
                'source_name': (
                    divs[1].get('div', [])[0]
                    .get('div', {})
                    .get('div', {})
                    .get('text', 'N/A')
                    if len(divs) > 1 and isinstance(divs[1].get('div', []), list)
                    else 'N/A'
                ),

                # --- NEW FIELD ---
                'publish_date': today_date
            }
            related_articles.append(article_data)

    # --- FINAL OUTPUT ---
    complete_news_data = {
        'primary_article': news_data,
        'related_articles': related_articles,
        'total_related_articles': len(related_articles)
    }

    return complete_news_data

# %% [markdown]
# ## printing the format in which the json stores the data for a single news card

# %%
news_item = get_news_data(dom_structures[2])
import pprint
pprint.pprint(news_item)
# Out:
# {'primary_article': {'article_link': 'https://news.google.com.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#                      'author': 'By Sam Tobin',
#                      'featured_image': '/api/attachments/CC8iK0NnNDBTbWszVlRoeVprdHlSelp3VFJERUF4aW1CU2dLTWdhbGRJcXRRUVU=-w280-h168-p-df',
#                      'headline': 'By Sam Tobin',
#                      'publish_date': '24-10-2025',
#                      'source_logo': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.reuters.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#                      'source_name': 'Reuters'},
#  'related_articles': [{'article_link': 'https://news.google.com./read/CBMinAFBVV95cUxQMEF6cVduVUl2UGZDcWpPSkpYbVgwY0UxalBOOUd1OUlWTDRQMGlPb2l4R0VpSXY3cDc3X1BEX0F3djBzeGpiR25xZklvWXhHdjVGcHlZLXp2c0dybkNoOEpHR1k0QlM4b2U4N2xWQnNqb2FLMk1na2FWR2lvbGpJLWJ2NURvbzJ4VmZGVVJxTFVwVkMyUVBqT3pXalE?hl=en-IN&gl=IN&ceid=IN%3Aen',
#                        'author': 'N/A',
#                        'headline': 'N/A',
#                        'publish_date': '24-10-2025',
#                        'source_logo': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.ndtv.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#                        'source_name': 'NDTV'},
#                       {'article_link': 'https://news.google.com.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#                        'author': 'N/A',
#                        'headline': 'N/A',
#                        'publish_date': '24-10-2025',
#                        'source_logo': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.livemint.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#                        'source_name': 'Mint'},
#                       {'article_link': 'https://news.google.com.?hl=en-IN&gl=IN&ceid=IN%3Aen',
#                        'author': 'By Sonali Verma',
#                        'headline': 'By Sonali Verma',
#                        'publish_date': '24-10-2025',
#                        'source_logo': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.indiatoday.in&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL',
#                        'source_name': 'India Today'}],
#  'total_related_articles': 3}

# %% [markdown]
# ## 8. Saving the data in the json

# %%
import json

# Assuming get_news_data() is already defined as before

business_news_data = []

# Loop through all items in dom_structures
for i, dom in enumerate(dom_structures):
    try:
        news_item = get_news_data(dom)
        business_news_data.append(news_item)
        print(f"Processed item {i + 1}/{len(dom_structures)}")
    except Exception as e:
        print(f"Error processing item {i + 1}: {e}")

# Save to JSON file
with open("business_news.json", "w", encoding="utf-8") as f:
    json.dump(business_news_data, f, ensure_ascii=False, indent=2)

print("\n✅ File 'business_news.json' saved successfully in the working directory!")
# Out:
# Processed item 1/69
# Processed item 2/69
# Processed item 3/69
# Processed item 4/69
# Processed item 5/69
# Processed item 6/69
# Processed item 7/69
# Processed item 8/69
# Processed item 9/69
# Processed item 10/69
# Processed item 11/69
# Processed item 12/69
# Processed item 13/69
# Processed item 14/69
# Processed item 15/69
# Processed item 16/69
# Processed item 17/69
# Processed item 18/69
# Processed item 19/69
# Processed item 20/69
# Processed item 21/69
# Processed item 22/69
# Processed item 23/69
# Processed item 24/69
# Processed item 25/69
# Processed item 26/69
# Processed item 27/69
# Processed item 28/69
# Processed item 29/69
# Processed item 30/69
# Processed item 31/69
# Processed item 32/69
# Processed item 33/69
# Processed item 34/69
# Processed item 35/69
# Processed item 36/69
# Processed item 37/69
# Processed item 38/69
# Processed item 39/69
# Processed item 40/69
# Processed item 41/69
# Processed item 42/69
# Processed item 43/69
# Processed item 44/69
# Processed item 45/69
# Processed item 46/69
# Processed item 47/69
# Processed item 48/69
# Processed item 49/69
# Processed item 50/69
# Processed item 51/69
# Processed item 52/69
# Processed item 53/69
# Processed item 54/69
# Processed item 55/69
# Processed item 56/69
# Processed item 57/69
# Processed item 58/69
# Processed item 59/69
# Processed item 60/69
# Processed item 61/69
# Processed item 62/69
# Processed item 63/69
# Processed item 64/69
# Processed item 65/69
# Processed item 66/69
# Processed item 67/69
# Processed item 68/69
# Processed item 69/69
#
# ✅ File 'business_news.json' saved successfully in the working directory!
